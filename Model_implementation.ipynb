# %%
# !pip install transformers accelerate bitsandbytes sentencepiece
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (5.1.0)
# Requirement already satisfied: accelerate in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (1.12.0)
# Requirement already satisfied: bitsandbytes in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (0.49.1)
# Requirement already satisfied: sentencepiece in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (0.2.1)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from transformers) (1.4.1)
# Requirement already satisfied: numpy>=1.17 in /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages (from transformers) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages (from transformers) (2023.6.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from transformers) (0.23.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: psutil in /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from accelerate) (2.10.0)
# Requirement already satisfied: filelock in /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (3.12.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2023.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: shellingham in /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (3.1.2)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from cuda-bindings==12.9.4->torch>=2.0.0->accelerate) (1.3.4)
# Requirement already satisfied: typer>=0.23.1 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from typer-slim->transformers) (0.23.1)
# Requirement already satisfied: anyio in /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.7.1)
# Requirement already satisfied: certifi in /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2023.5.7)
# Requirement already satisfied: httpcore==1.* in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.4)
# Requirement already satisfied: h11>=0.16 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages (from typer>=0.23.1->typer-slim->transformers) (8.1.5)
# Requirement already satisfied: rich>=10.11.0 in /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages (from typer>=0.23.1->typer-slim->transformers) (13.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr4/cs640/siddhank/.local/lib/python3.10/site-packages (from typer>=0.23.1->typer-slim->transformers) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages (from jinja2->torch>=2.0.0->accelerate) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages (from rich>=10.11.0->typer>=0.23.1->typer-slim->transformers) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages (from rich>=10.11.0->typer>=0.23.1->typer-slim->transformers) (2.15.1)
# Requirement already satisfied: sniffio>=1.1 in /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.3.0)
# Requirement already satisfied: exceptiongroup in /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.1.2)
# Requirement already satisfied: mdurl~=0.1 in /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.23.1->typer-slim->transformers) (0.1.2)
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
import torch

model_id = "Qwen/Qwen2.5-32B-Instruct"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    llm_int8_enable_fp32_cpu_offload=True   
)

tokenizer = AutoTokenizer.from_pretrained(model_id)

model = AutoModelForCausalLM.from_pretrained(
    model_id,
    quantization_config=bnb_config,
    device_map="auto"
)

messages = [
    {"role": "user", "content": "Explain transformers in simple terms."}
]

text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

inputs = tokenizer(text, return_tensors="pt").to("cuda")

outputs = model.generate(
    **inputs,
    max_new_tokens=120,
    temperature=0.7
)

print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Loading weights:   0%|          | 0/771 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# system
# You are Qwen, created by Alibaba Cloud. You are a helpful assistant.
# user
# Explain transformers in simple terms.
# assistant
# Transformers are a type of artificial intelligence model used for processing and understanding language. Think of them as very smart tools that can read, understand, and generate human language.
#
# Here's how they work in simple terms:
#
# 1. **Attention Mechanism**: Instead of reading text one word at a time like we do, transformers look at the whole sentence (or even longer texts) all at once. They pay more attention to some words than others based on their importance in the sentence. This helps them understand the context better.
#
# 2. **Learning from Examples**: Transformers learn by being shown millions of examples of
